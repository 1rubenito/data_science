# %% [markdown]
# <a href="https://colab.research.google.com/github/1rubenito/data_science/blob/main/Panorama_da_COVID_19_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# ## Análise de dados COVID-19 no Brasil
# ### Do primeiro caso à primeira aplicação da vacina
#
# *por* *`Rubens Gianfaldoni`*
#
# ---

# %% [markdown]
# <center><img alt="covid19" width="38%" src="https://www.acessa.com/saude/arquivo/noticias/2021/02/03-juiz-fora-tem-mais-quatro-mortes-205-novos-casos-covid-19/foto.jpg">
#
#
# A COVID-19 é uma doença causada pelo coronavírus, denominado SARS-CoV-2. Os sintomas podem variar de infecções assintomáticas a quadros graves.
# Aproximadamente 20% dos casos positivos precisam de atendimento hospitalar, os outros 80% dos casos podem ser assintomáticos ou com poucos sintomas.
# No Brasil, o [primeiro caso](https://bit.ly/2ZRjD2L) identificado aconteceu em 26 de fevereiro de 2020. Um cidadão que havia retornado de uma viagem da Itália.
# Em 17 de março ocorre a [primeira morte](https://bit.ly/3swuQ4Z) em decorrência do vírus, na cidade de São Paulo.

# %% [markdown]
# # Origem dos dados
#
# Os dados para esse `dataset` foram extraídos do site [Our World in Data](https://ourworldindata.org/coronavirus).
# Existem muitas variáveis no `dataset` que explicam porque alguns países estão avançando no combate ao [vírus](https://bit.ly/3uCRjPR) e outros estão com casos muito acima dos demais.
#
# *No Brasil alguns problemas com a atualização dos dados comprometem a avaliação e o entendimento dos gráficos. Por exemplo, alguns estados não atualizam seus dados aos fins de semana, o que acarreta que todo montante de dados do fim de semana, acabe entrando na próxima segunda-feira. Isso significa que em alguns estados o primeiro dia útil da semana sempre estará com casos divergentes dos demais dias da semana, tornando assim a avaliação com erros pontuais de crescimento de casos.*
#
# ---
# ---
#
# #### O `dataset` contém muitas variáveis. Traduzi todas para melhor entendimento. Usaremos algumas durante a análise.
#
# ---
# * iso_code  | `sigla usada para identificar os países`
# * continent | `continente do país`
# * location  | `localização geográfica do país`
# * data      | `data de captação dos dados`
# * total_cases | `total de casos confirmados`
# * new_cases | `novos casos confirmados`
# * new_cases_smoothed | `resumo dos últimos 7 dias de novos casos`
# * total_deaths | `total de mortes`
# * new_deaths | `novo número de mortos`
# * new_deaths_smoothed | `resumo dos últimos 7 dias de novas mortes`
# * total_cases_per_million | `casos totais por milhão de habitante`
# * new_cases_per_million | `novos casos por milhão de habitante`
# * new_cases_smoothed_per_million | `resumo dos últimos 7 dias de novos casos por milhão de habitante`
# * total_deaths_per_million | `total de mortes por milhão de habitante`
# * new_deaths_per_million | `novas mortes por milhão de habitante`
# * new_deaths_smoothed_per_million | `resumo dos últimos 7 dias de novas mortes por milhão de habitante`
# * reproduction_rate | `taxa de reprodução em tempo-real do vírus`
# * icu_patients | `taxa de pacientes em UTI, por dia`
# * icu_patiens_per_milion | `taxa de pacientes em UTI, por dia, por milhão de habitante`
# * hosp_patients | `taxa de ocupação de hospitais, por dia`
# * hosp_patients_per_milion | `taxa de ocupação de hospitais, por dia, por milhão de habitante`
# * weekly_icu_admissions | `número de pacientes enviados para UTI, por semana`
# * weekly_icu_admissions_per_milion | `número de pacientes enviados para UTI por semana, por milhão de habitante`
# * weekly_hosp_admissions | `número de pacientes enviados para hospitais, por semana`
# * weekly_hosp_admissions_per_milion | `número de pacientes enviados para hospitais, por semana, por milhão de habitante`
# * total_tests | `testes realizados`
# * new_tests | `novos testes, acumulados de dias`
# * total_tests_per_thousand | `total de testes para cada mil pessoas`
# * new_tests_per_thousand | `novos testes para cada mil pessoas`
# * new_tests_smoothed | `resumo dos últimos 7 dias de novos testes`
# * new_tests_smoothed_per_thousand | `resumo dos últimos 7 dias de novos testes,a cada mil pessoas`
# * positive_rate | `resultado de testes positivos na média de 7 dias`
# * tests_per_case | `quantos testes foram realizados para cada caso positivo do vírus`
# * tests_units | `localização de onde vem os resultados dos testes`
# * total_vaccinations | `total de doses da vacina`
# * people_vaccinated | `total de pessoas vacinadas`
# * people_fully_vaccinated | `total de pessoas que tomara todas as doses`
# * new_vaccinations | `novas doses de vacinas recebidas`
# * new_vaccinations_smoothed | `resumo de 7 dias de novas doses de vacinas recebidas`
# * total_vaccinations_per_hundred | `total de vacinas recebidas para cada 100 pessoas`
# * people_vaccinated_per_hundred | `pessoas vacinadas para cada 100 pessoas`
# * people_fully_vaccinated_per_hundred | `pessoas que receberam todas as doses da vacina para cada 100 pessoas`
# * new_vaccinations_smoothed_per_milion | `resumo de 7 dias de novas doses recebidas, para cada milhão de habitante`
# * stringency_index | `índice de isolamento`
# * population | `população`
# * population_density | `densidade demográfica`
# * median_age | `média de idade`
# * aged_65_older | `população com mais de 65 anos de idade`
# * aged_70_older | `população com mais de 70 anos de idade`
# * gdp_per_capita | `produto interno bruto(PIB)`
# * extreme_poverty | `população que vive em caso de extrema pobreza`
# * cardiovasc_death_rate | `taxa de mortalidade por doenças cardiovasculares`
# * diabetes_prevalence | `total de diabéticos em uma população entre 20 e 79 anos`
# * female_smokers | `fumantes do sexo feminino`
# * male_smokers | `fumantes do sexo masculino`
# * handwashing_facilities | `parcela da população com acesso à higienização básica das mãos`
# * hospital_beds_per_thousand | `taxa de leitos em hospitais para cada mil pessoas`
# * life_expectancy | `espectativa de vida ao nascer em 2019`
# * human_development_index | `índice de desenvolvimento humano`
# ---
# ---
# ---
#
# <center>
#
# #Importando os dados
#
# Vamos começar importando as bibliotecas necessárias para essa análise.
# Usaremos esta [base de dados](https://covid.ourworldindata.org/data/owid-covid-data.csv).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

DATA_PATH = "https://covid.ourworldindata.org/data/owid-covid-data.csv"
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# <center>
#
#  Antes de prosseguir, vamos descobrir qual o tamanho do nosso `dataset`

# %%
print("Países: {} linhas".format(df.shape[0]))
print("Variáveis: {} colunas".format(df.shape[1]))
# Out:
# Países: 79277 linhas
# Variáveis: 59 colunas

# %% [markdown]
# <center>
#
#
# As 5 primeiras linhas do `dataset` nos mostram a quantidade de variáveis e suas características. Dessa maneira podemos começar um filtro do que usaremos a seguir.

# %%
df.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %% [markdown]
# Algumas colunas como:
# * `new_cases_smoothed`
# * `new_deaths`
# * `total_deaths`, mostram como existe uma grande quantidade valores nulos ou ausentes. A seguir vamos tratá-los para não atrapalharem a análise.

# %% [markdown]
# ###Limpeza de dados nulos ou ausentes

# %% [markdown]
# Abaixo a quantidade de valores nulos ou ausentes do `dataset`

# %%
df.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 3868
# location                                     0
# date                                         0
# total_cases                               1578
# new_cases                                 1580
# new_cases_smoothed                        2581
# total_deaths                             11007
# new_deaths                               10849
# new_deaths_smoothed                       2581
# total_cases_per_million                   2000
# new_cases_per_million                     2002
# new_cases_smoothed_per_million            2998
# total_deaths_per_million                 11416
# new_deaths_per_million                   11258
# new_deaths_smoothed_per_million           2998
# reproduction_rate                        15431
# icu_patients                             70974
# icu_patients_per_million                 70974
# hosp_patients                            69333
# hosp_patients_per_million                69333
# weekly_icu_admissions                    78551
# weekly_icu_admissions_per_million        78551
# weekly_hosp_admissions                   77942
# weekly_hosp_admissions_per_million       77942
# new_tests                                43237
# total_tests                              43489
# total_tests_per_thousand                 43489
# new_tests_per_thousand                   43237
# new_tests_smoothed                       38035
# new_tests_smoothed_per_thousand          38035
# positive_rate                            39361
# tests_per_case                           39915
# tests_units                              36671
# total_vaccinations                       73095
# people_vaccinated                        73700
# people_fully_vaccinated                  75388
# new_vaccinations                         74048
# new_vaccinations_smoothed                69555
# total_vaccinations_per_hundred           73095
# people_vaccinated_per_hundred            73700
# people_fully_vaccinated_per_hundred      75388
# new_vaccinations_smoothed_per_million    69555
# stringency_index                         11938
# population                                 493
# population_density                        5381
# median_age                                7584
# aged_65_older                             8406
# aged_70_older                             7987
# gdp_per_capita                            7305
# extreme_poverty                          30195
# cardiovasc_death_rate                     6708
# diabetes_prevalence                       5746
# female_smokers                           22299
# male_smokers                             23135
# handwashing_facilities                   42835
# hospital_beds_per_thousand               12928
# life_expectancy                           4016
# human_development_index                   6762
# dtype: int64

# %% [markdown]
# Começando a limpeza de dados ausentes mostrando a porcentagem por coluna, em ordem crescente.

# %%
ant_nulos = (df.isnull().sum() / df.shape[0]).sort_values()
print(ant_nulos)
# Out:
# iso_code                                 0.000000
# location                                 0.000000
# date                                     0.000000
# population                               0.006219
# total_cases                              0.019905
# new_cases                                0.019930
# total_cases_per_million                  0.025228
# new_cases_per_million                    0.025253
# new_cases_smoothed                       0.032557
# new_deaths_smoothed                      0.032557
# new_deaths_smoothed_per_million          0.037817
# new_cases_smoothed_per_million           0.037817
# continent                                0.048791
# life_expectancy                          0.050658
# population_density                       0.067876
# diabetes_prevalence                      0.072480
# cardiovasc_death_rate                    0.084615
# human_development_index                  0.085296
# gdp_per_capita                           0.092145
# median_age                               0.095665
# aged_70_older                            0.100748
# aged_65_older                            0.106033
# new_deaths                               0.136849
# total_deaths                             0.138842
# new_deaths_per_million                   0.142008
# total_deaths_per_million                 0.144001
# stringency_index                         0.150586
# hospital_beds_per_thousand               0.163074
# reproduction_rate                        0.194647
# female_smokers                           0.281280
# male_smokers                             0.291825
# extreme_poverty                          0.380880
# tests_units                              0.462568
# new_tests_smoothed                       0.479773
# new_tests_smoothed_per_thousand          0.479773
# positive_rate                            0.496500
# tests_per_case                           0.503488
# handwashing_facilities                   0.540321
# new_tests_per_thousand                   0.545391
# new_tests                                0.545391
# total_tests_per_thousand                 0.548570
# total_tests                              0.548570
# hosp_patients_per_million                0.874566
# hosp_patients                            0.874566
# new_vaccinations_smoothed                0.877367
# new_vaccinations_smoothed_per_million    0.877367
# icu_patients                             0.895266
# icu_patients_per_million                 0.895266
# total_vaccinations_per_hundred           0.922020
# total_vaccinations                       0.922020
# people_vaccinated_per_hundred            0.929652
# people_vaccinated                        0.929652
# new_vaccinations                         0.934041
# people_fully_vaccinated_per_hundred      0.950944
# people_fully_vaccinated                  0.950944
# weekly_hosp_admissions_per_million       0.983160
# weekly_hosp_admissions                   0.983160
# weekly_icu_admissions_per_million        0.990842
# weekly_icu_admissions                    0.990842
# dtype: float64

# %% [markdown]
# A seguir removeremos os dados ausentes, pois para a nossa análise não servem neste momento. Para ajudar usaremos o comando `df.columns` para nos mostrar todas as colunas para facilitar na formação da lista de remoção.

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %% [markdown]
# Ao mostrar a quantidade de dados ausentes, as colunas `iso_code`, `location` e `date` foram as únicas que apresentavam o preenchimento total de dados. Abaixo vamos remover os dados ausentes das colunas que usaremos na análise e mostrar um resultado de *antes* e *depois*.

# %%
df_clean = df.dropna(subset=['continent', 'total_cases', 'new_cases',
       'total_deaths', 'new_deaths','reproduction_rate','icu_patients',
       'hosp_patients','hosp_patients_per_million','weekly_hosp_admissions_per_million', 
       'new_tests', 'total_tests','positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
       'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
       'stringency_index','population', 'population_density', 'median_age','aged_65_older',
       'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers','life_expectancy', 'human_development_index'])


print("Antes da remoção de dados nulos: {}".format(df.shape))
print("Após remoção de dados nulos: {}".format(df_clean.shape))
# Out:
# Antes da remoção de dados nulos: (79277, 59)
# Após remoção de dados nulos: (74, 59)

# %%
df_clean.isnull().sum()
# Out:
# iso_code                                  0
# continent                                 0
# location                                  0
# date                                      0
# total_cases                               0
# new_cases                                 0
# new_cases_smoothed                        0
# total_deaths                              0
# new_deaths                                0
# new_deaths_smoothed                       0
# total_cases_per_million                   0
# new_cases_per_million                     0
# new_cases_smoothed_per_million            0
# total_deaths_per_million                  0
# new_deaths_per_million                    0
# new_deaths_smoothed_per_million           0
# reproduction_rate                         0
# icu_patients                              0
# icu_patients_per_million                  0
# hosp_patients                             0
# hosp_patients_per_million                 0
# weekly_icu_admissions                    49
# weekly_icu_admissions_per_million        49
# weekly_hosp_admissions                    0
# weekly_hosp_admissions_per_million        0
# new_tests                                 0
# total_tests                               0
# total_tests_per_thousand                  0
# new_tests_per_thousand                    0
# new_tests_smoothed                        0
# new_tests_smoothed_per_thousand           0
# positive_rate                             0
# tests_per_case                            0
# tests_units                               0
# total_vaccinations                        0
# people_vaccinated                         0
# people_fully_vaccinated                   0
# new_vaccinations                          0
# new_vaccinations_smoothed                 0
# total_vaccinations_per_hundred            0
# people_vaccinated_per_hundred             0
# people_fully_vaccinated_per_hundred       0
# new_vaccinations_smoothed_per_million     0
# stringency_index                          0
# population                                0
# population_density                        0
# median_age                                0
# aged_65_older                             0
# aged_70_older                             0
# gdp_per_capita                            0
# extreme_poverty                           0
# cardiovasc_death_rate                     0
# diabetes_prevalence                       0
# female_smokers                            0
# male_smokers                              0
# handwashing_facilities                   74
# hospital_beds_per_thousand                0
# life_expectancy                           0
# human_development_index                   0
# dtype: int64

# %% [markdown]
# Passo importante para seguir é converter o formato `datetime` para melhor uso na análise

# %%
df.date = pd.to_datetime(df.date)

# %% [markdown]
# Iniciando a análise de dados, vamos mostrar como estava o Brasil no mês de *fevereiro* de 2020, em relação a pandemia.

# %%
o_brasil = df.loc[df.location == 'Brazil'].copy()

# %% [markdown]
# O `dataset` possui muitas colunas que neste momento não vão servir para nossa análise, então iremos excluir algumas colunas.

# %%
novo_br = o_brasil.drop(['iso_code','new_cases_smoothed','new_deaths',
       'new_deaths_smoothed', 'total_cases_per_million',
       'new_cases_per_million', 'new_cases_smoothed_per_million',
       'total_deaths_per_million', 'new_deaths_per_million',
       'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
       'icu_patients_per_million', 'hosp_patients',
       'hosp_patients_per_million', 'weekly_icu_admissions',
       'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
       'weekly_hosp_admissions_per_million', 'new_tests',
       'total_tests_per_thousand', 'new_tests_per_thousand',
       'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
       'positive_rate', 'tests_per_case', 'tests_units',
       'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
       'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
       'new_vaccinations_smoothed_per_million', 'stringency_index',
       'population', 'population_density', 'median_age', 'aged_65_older',
       'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy', 'human_development_index'], axis=1)

# %% [markdown]
# Seguimos então agora com um `dataset` melhor adaptado para nossa análise. Abaixo qual era o número de casos no Brasil em *26 de fevereiro*.

# %%
novo_br.loc[df.date == '2020-02-26']
# Out:
#            continent location  ... people_fully_vaccinated  new_vaccinations
# 10152  South America   Brazil  ...                     NaN               NaN
#
# [1 rows x 11 columns]

# %% [markdown]
# No dia *26 de fevereiro de 2020*, foi confirmado o primeiro caso no Brasil da COVID-19. Mas, nesta mesma data, qual era o país com maior números de casos?

# %%
total_casos_fev = df[df['date'] == '2020-02-26'].sort_values(by='total_cases', ascending=False)
total_casos_fev
# Out:
#        iso_code      continent  ... life_expectancy human_development_index
# 77753  OWID_WRL            NaN  ...           72.58                   0.737
# 3731   OWID_ASI            NaN  ...             NaN                     NaN
# 15042       CHN           Asia  ...           76.91                   0.761
# 66240       KOR           Asia  ...           83.03                   0.916
# 33372  OWID_INT            NaN  ...             NaN                     NaN
# ...         ...            ...  ...             ...                     ...
# 48154       MAR         Africa  ...           76.68                   0.686
# 56262       PER  South America  ...           76.74                   0.777
# 62401       SRB         Europe  ...           76.00                   0.806
# 64414       SVN         Europe  ...           81.32                   0.917
# 65394       ZAF         Africa  ...           64.13                   0.709
#
# [70 rows x 59 columns]

# %% [markdown]
# Podemos ver acima que o país na época com mais casos era a `China` com `78.166`. Na época era o epicentro da pandemia, pois foram onde apareceram os [primeiros casos no mundo](https://bit.ly/31IpTe9).

# %% [markdown]
# Um pouco menos de 1 mês depois do primeiro caso confirmado no Brasil aconteceu a primeira morte pelo vírus em *17 de março de 2020*. Vamos analisar como estavam os números de mortes em relação aos 5 primeiros no mundo nesta mesma data.

# %%
total_mortes_mar = df.loc[df['date'] == '2020-03-17', ['date', 'location', 'total_deaths']].sort_values(by='total_deaths', ascending=False)[4:9].reset_index(drop=True)
total_mortes_mar
# Out:
#         date location  total_deaths
# 0 2020-03-17    China        3230.0
# 1 2020-03-17    Italy        2503.0
# 2 2020-03-17     Iran         988.0
# 3 2020-03-17    Spain         533.0
# 4 2020-03-17   France         149.0

# %% [markdown]
# Na mesma data da primeira morte pelo vírus no Brasil, como visto na coluna `total_deaths`, assim estavam os 5 maiores países com mortes:
#
# 1. China - *3.230*
# 2. Itália - *2.503*
# 3. Irã - *988*
# 4. Espanha - *533*
# 5. França - *149*

# %% [markdown]
# Abaixo os números da variável `total_deaths` dos 5 países plotado em um gráfico de barras:

# %%
total5 = df.loc[df['date'] == '2020-03-17', ['location', 'total_deaths']].sort_values(by='total_deaths', ascending=False)[4:9]

fig, ax = plt.subplots()

ax.bar('location', 'total_deaths', data=total5)
plt.xticks(rotation=45, ha='left')
plt.show()

# %% [markdown]
# Em 17 de janeiro de 2021, o Brasil aplicou a primeira vacina. Aprovada pela Anvisa, a Coronavac foi aplica em [Mônica Calazans](https://bit.ly/3e2g4z3) no Hospital das Clínicas. Vamos analisar qual a situação do Brasil, quase um ano após o primeiro caso.

# %%
old_br =novo_br.loc[novo_br['date'] == '2020-02-26', ['date', 'location', 'total_cases', 'new_cases', 'total_deaths']].sort_values(by='total_cases').reset_index(drop=True)
old_br.set_index('date', inplace=True)
old_br # PRIMEIRO CASO NO BRASIL
# Out:
#            location  total_cases  new_cases  total_deaths
# date
# 2020-02-26   Brazil          1.0        1.0           NaN

# %%
new_br = novo_br.loc[novo_br['date'] == '2021-01-17', ['date', 'location', 'total_cases', 'new_cases', 'total_deaths']].sort_values(by='total_cases').reset_index(drop=True)
new_br.set_index('date', inplace=True)
new_br # QUASE UM ANO DEPOIS
# Out:
#            location  total_cases  new_cases  total_deaths
# date
# 2021-01-17   Brazil    8488099.0    33040.0      209847.0

# %% [markdown]
# *A primeira vacina era aplicada no Brasil, enquanto o número de casos, novos casos e mortes subia drasticamente.*

# %% [markdown]
# Vamos comparar, qual era o país com mais pessoas vacinadas no dia que o Brasil aplicada sua primeira dose:

# %%
df.loc[df['date'] == '2021-01-17', ['date', 'location', 'people_vaccinated']].sort_values(by='people_vaccinated', ascending=False)[6:16]
# Out:
#             date location  people_vaccinated
# 35399 2021-01-17   Israel          2205393.0
# 35828 2021-01-17    Italy          1210256.0
# 27851 2021-01-17  Germany          1190249.0
# 13281 2021-01-17   Canada           539581.0
# 57414 2021-01-17   Poland           468795.0
# 46382 2021-01-17   Mexico           468708.0
# 26246 2021-01-17   France           391910.0
# 32878 2021-01-17    India           224301.0
# 58620 2021-01-17  Romania           203310.0
# 19671 2021-01-17  Denmark           169294.0

# %% [markdown]
# Como visto acima, `Israel` era o país com mais pessoas vacinadas, passando de 2 milhões de habitantes vacinados.

# %% [markdown]
# Podemos correlacionar o número alto de mortes ao baixo índice do PIB, como visto abaixo em um gráfico do tipo *dispersão*:

# %%
fig, ax = plt.subplots()

df.plot.scatter(x ='gdp_per_capita', y='total_deaths', ax=ax, s=0.5)
ax.set_title('Total de mortes em relação ao PIB')
ax.set_xlabel('produto interno bruto')
ax.set_ylabel('total de mortes')

plt.tight_layout()

# %% [markdown]
# ## Conclusão
#
# Neste `dateset` foi apresentado, além de dados totais da [pandemia da COVID19]((https://bit.ly/3uCRjPR) pelo mundo, alguns detalhes importantes sobre como foi o comportamento do vírus no Brasil, do primeiro dia até a primeira aplicação da vacina.
# Desde o primeiro caso, até os momentos atuais, o país vem sofrendo duros golpes com cada vez mais casos, mais mortes, mais origens de cepas locais e desrespeito quanto as orientações de isolamento social.
#
#
#
#
#
# Pontos importantes apareceram na análise como:
#
# *   o Brasil durante os primeiros meses de pandemia, não foi atacado pelo vírus, ferozmente como os países da Ásia, Europa e América do Norte.
#
#
# *   o Brasil demorou muito, em relação aos países com o mesmo número de tempo com vírus, para começar a vacinação, visto na análise que, enquanto o Brasil aplicava a primeira dose, países como : Israel, Itália e Alemanha, já passavam de 1milhão de pessoas vacinadas. Esses países se beneficiaram muito de terem começado antes a vacinar, puderam diminuir o isolamento e as pessoas retomarem ‘o novo normal’ com mais rapidez.
#
#
# * países com menor poderio de riqueza sofrem muito com mais mortes. E concluímos que quanto menor o PIB(Produto Interno Bruto), maior a chance de sua população sofrer com o vírus.
